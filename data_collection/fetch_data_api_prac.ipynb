# %%
import pandas as pd
import requests

# %%
url = "https://alpha-vantage.p.rapidapi.com/query"
params = {
    "function": "TIME_SERIES_DAILY",
    "symbol": "MSFT",
    "outputsize": "compact",
    "datatype": "json"
}

headers = {
    "x-rapidapi-host": "alpha-vantage.p.rapidapi.com",
    "x-rapidapi-key": "885b3131d9msh816a48785e2f145p100ad9jsnae97fdad8ab0"
}

# %%
response = requests.get(url, params=params, headers=headers)

# %%
print(response.status_code)
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'MSFT',
#   '3. Last Refreshed': '2026-02-27',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2026-02-27': {'1. open': '390.8800',
#    '2. high': '396.8200',
#    '3. low': '389.8800',
#    '4. close': '392.7400',
#    '5. volume': '51367196'},
#   '2026-02-26': {'1. open': '404.7100',
#    '2. high': '407.4900',
#    '3. low': '398.7400',
#    '4. close': '401.7200',
#    '5. volume': '34405869'},
#   '2026-02-25': {'1. open': '390.5250',
#    '2. high': '401.4700',
#    '3. low': '390.1600',
#    '4. close': '400.6000',
#    '5. volume': '43625483'},
#   '2026-02-24': {'1. open': '384.1400',
#    '2. high': '389.3600',
#    '3. low': '381.7100',
#    '4. close': '389.0000',
#    '5. volume': '33884653'},
#   '2026-02-23': {'1. open': '395.0000',
#    '2. high': '395.3600',
#    '3. low': '383.1000',
#    '4. close': '384.4700',
#    '5. volume': '43238273'},
#   '2026-02-20': {'1. open': '396.1100',
#    '2. high': '400.1159',
#    '3. low': '395.1600',
#    '4. close': '397.2300',
#    '5. volume': '34015249'},
#   '2026-02-19': {'1. open': '400.6900',
#    '2. high': '404.4300',
#    '3. low': '396.6700',
#    '4. close': '398.4600',
#    '5. volume': '28234001'},
#   '2026-02-18': {'1. open': '398.1300',
#    '2. high': '402.5600',
#    '3. low': '396.3200',
#    '4. close': '399.6000',
#    '5. volume': '23223417'},
#   '2026-02-17': {'1. open': '399.2200',
#    '2. high': '400.5200',
#    '3. low': '394.5250',
#    '4. close': '396.8600',
#    '5. volume': '32078794'},
#   '2026-02-13': {'1. open': '404.4500',
#    '2. high': '405.5400',
#    '3. low': '398.0500',
#    '4. close': '401.3200',
#    '5. volume': '34091553'},
#   '2026-02-12': {'1. open': '405.0000',
#    '2. high': '406.2000',
#    '3. low': '398.0100',
#    '4. close': '401.8400',
#    '5. volume': '40802362'},
#   '2026-02-11': {'1. open': '416.1750',
#    '2. high': '416.4600',
#    '3. low': '401.0100',
#    '4. close': '404.3700',
#    '5. volume': '42491012'},
#   '2026-02-10': {'1. open': '419.6200',
#    '2. high': '423.6800',
#    '3. low': '412.7000',
#    '4. close': '413.2700',
#    '5. volume': '44857850'},
#   '2026-02-09': {'1. open': '404.8500',
#    '2. high': '414.8900',
#    '3. low': '400.8700',
#    '4. close': '413.6000',
#    '5. volume': '45480526'},
#   '2026-02-06': {'1. open': '399.1650',
#    '2. high': '401.7900',
#    '3. low': '392.9200',
#    '4. close': '401.1400',
#    '5. volume': '53515311'},
#   '2026-02-05': {'1. open': '407.4400',
#    '2. high': '408.3000',
#    '3. low': '392.3200',
#    '4. close': '393.6700',
#    '5. volume': '66289247'},
#   '2026-02-04': {'1. open': '411.0000',
#    '2. high': '419.8000',
#    '3. low': '409.2400',
#    '4. close': '414.1900',
#    '5. volume': '45012374'},
#   '2026-02-03': {'1. open': '422.0100',
#    '2. high': '422.0500',
#    '3. low': '408.5600',
#    '4. close': '411.2100',
#    '5. volume': '60076532'},
#   '2026-02-02': {'1. open': '430.2350',
#    '2. high': '430.7360',
#    '3. low': '422.2500',
#    '4. close': '423.3700',
#    '5. volume': '42219858'},
#   '2026-01-30': {'1. open': '439.1700',
#    '2. high': '439.6000',
#    '3. low': '426.4500',
#    '4. close': '430.2900',
#    '5. volume': '58566819'},
#   '2026-01-29': {'1. open': '439.9900',
#    '2. high': '442.5000',
#    '3. low': '421.0200',
#    '4. close': '433.5000',
#    '5. volume': '128855323'},
#   '2026-01-28': {'1. open': '483.2100',
#    '2. high': '483.7400',
#    '3. low': '478.0000',
#    '4. close': '481.6300',
#    '5. volume': '36875403'},
#   '2026-01-27': {'1. open': '473.7000',
#    '2. high': '482.8700',
#    '3. low': '473.1600',
#    '4. close': '480.5800',
#    '5. volume': '29088664'},
#   '2026-01-26': {'1. open': '465.3050',
#    '2. high': '474.2500',
#    '3. low': '462.0000',
#    '4. close': '470.2800',
#    '5. volume': '29291235'},
#   '2026-01-23': {'1. open': '451.8700',
#    '2. high': '471.1000',
#    '3. low': '450.5300',
#    '4. close': '465.9500',
#    '5. volume': '38000159'},
#   '2026-01-22': {'1. open': '447.6200',
#    '2. high': '452.8400',
#    '3. low': '444.7000',
#    '4. close': '451.1400',
#    '5. volume': '25349378'},
#   '2026-01-21': {'1. open': '452.5950',
#    '2. high': '452.6900',
#    '3. low': '438.6800',
#    '4. close': '444.1100',
#    '5. volume': '37980510'},
#   '2026-01-20': {'1. open': '451.2150',
#    '2. high': '456.8000',
#    '3. low': '449.2800',
#    '4. close': '454.5200',
#    '5. volume': '25973898'},
#   '2026-01-16': {'1. open': '457.8300',
#    '2. high': '463.1900',
#    '3. low': '456.4800',
#    '4. close': '459.8600',
#    '5. volume': '34246650'},
#   '2026-01-15': {'1. open': '464.1200',
#    '2. high': '464.2500',
#    '3. low': '455.9000',
#    '4. close': '456.6600',
#    '5. volume': '23225839'},
#   '2026-01-14': {'1. open': '466.4600',
#    '2. high': '468.2000',
#    '3. low': '457.1700',
#    '4. close': '459.3800',
#    '5. volume': '28184302'},
#   '2026-01-13': {'1. open': '474.6750',
#    '2. high': '475.7799',
#    '3. low': '465.9500',
#    '4. close': '470.6700',
#    '5. volume': '28545800'},
#   '2026-01-12': {'1. open': '476.6700',
#    '2. high': '480.9900',
#    '3. low': '475.6803',
#    '4. close': '477.1800',
#    '5. volume': '23519895'},
#   '2026-01-09': {'1. open': '474.0600',
#    '2. high': '479.8200',
#    '3. low': '472.2001',
#    '4. close': '479.2800',
#    '5. volume': '18491036'},
#   '2026-01-08': {'1. open': '481.2400',
#    '2. high': '482.6600',
#    '3. low': '475.8600',
#    '4. close': '478.1100',
#    '5. volume': '18162616'},
#   '2026-01-07': {'1. open': '479.7550',
#    '2. high': '489.7000',
#    '3. low': '477.9500',
#    '4. close': '483.4700',
#    '5. volume': '25564196'},
#   '2026-01-06': {'1. open': '473.8000',
#    '2. high': '478.7367',
#    '3. low': '469.7500',
#    '4. close': '478.5100',
#    '5. volume': '23037665'},
#   '2026-01-05': {'1. open': '474.0550',
#    '2. high': '476.0700',
#    '3. low': '469.5000',
#    '4. close': '472.8500',
#    '5. volume': '25250260'},
#   '2026-01-02': {'1. open': '484.3850',
#    '2. high': '484.6600',
#    '3. low': '470.1600',
#    '4. close': '472.9400',
#    '5. volume': '25571567'},
#   '2025-12-31': {'1. open': '487.8400',
#    '2. high': '488.1400',
#    '3. low': '483.3000',
#    '4. close': '483.6200',
#    '5. volume': '15601554'},
#   '2025-12-30': {'1. open': '485.9300',
#    '2. high': '489.6800',
#    '3. low': '485.5000',
#    '4. close': '487.4800',
#    '5. volume': '13944512'},
#   '2025-12-29': {'1. open': '484.8550',
#    '2. high': '488.3500',
#    '3. low': '484.1800',
#    '4. close': '487.1000',
#    '5. volume': '10893408'},
#   '2025-12-26': {'1. open': '486.7050',
#    '2. high': '488.1200',
#    '3. low': '485.9600',
#    '4. close': '487.7100',
#    '5. volume': '8842175'},
#   '2025-12-24': {'1. open': '485.6800',
#    '2. high': '489.1625',
#    '3. low': '484.8300',
#    '4. close': '488.0200',
#    '5. volume': '5855880'},
#   '2025-12-23': {'1. open': '484.9800',
#    '2. high': '487.8300',
#    '3. low': '484.7400',
#    '4. close': '486.8500',
#    '5. volume': '14683582'},
#   '2025-12-22': {'1. open': '486.1200',
#    '2. high': '488.7300',
#    '3. low': '482.6900',
#    '4. close': '484.9200',
#    '5. volume': '16963019'},
#   '2025-12-19': {'1. open': '487.3600',
#    '2. high': '487.8500',
#    '3. low': '482.4900',
#    '4. close': '485.9200',
#    '5. volume': '70836105'},
#   '2025-12-18': {'1. open': '478.1900',
#    '2. high': '489.6000',
#    '3. low': '477.8900',
#    '4. close': '483.9800',
#    '5. volume': '28573545'},
#   '2025-12-17': {'1. open': '476.9050',
#    '2. high': '480.0000',
#    '3. low': '475.0000',
#    '4. close': '476.1200',
#    '5. volume': '24527176'},
#   '2025-12-16': {'1. open': '471.9050',
#    '2. high': '477.8900',
#    '3. low': '470.8800',
#    '4. close': '476.3900',
#    '5. volume': '20705560'},
#   '2025-12-15': {'1. open': '480.1000',
#    '2. high': '480.7205',
#    '3. low': '472.5200',
#    '4. close': '474.8200',
#    '5. volume': '23727694'},
#   '2025-12-12': {'1. open': '479.8200',
#    '2. high': '482.4500',
#    '3. low': '476.3400',
#    '4. close': '478.5300',
#    '5. volume': '21248102'},
#   '2025-12-11': {'1. open': '476.6300',
#    '2. high': '486.0300',
#    '3. low': '475.8600',
#    '4. close': '483.4700',
#    '5. volume': '24669180'},
#   '2025-12-10': {'1. open': '484.0300',
#    '2. high': '484.2500',
#    '3. low': '475.0800',
#    '4. close': '478.5600',
#    '5. volume': '35756229'},
#   '2025-12-09': {'1. open': '489.1000',
#    '2. high': '492.1200',
#    '3. low': '488.5001',
#    '4. close': '492.0200',
#    '5. volume': '14092776'},
#   '2025-12-08': {'1. open': '484.8850',
#    '2. high': '492.3000',
#    '3. low': '484.3800',
#    '4. close': '491.0200',
#    '5. volume': '20668450'},
#   '2025-12-05': {'1. open': '482.5150',
#    '2. high': '483.4000',
#    '3. low': '478.8801',
#    '4. close': '483.1600',
#    '5. volume': '22608710'},
#   '2025-12-04': {'1. open': '479.7600',
#    '2. high': '481.3220',
#    '3. low': '476.4900',
#    '4. close': '480.8400',
#    '5. volume': '22318155'},
#   '2025-12-03': {'1. open': '476.3200',
#    '2. high': '484.2400',
#    '3. low': '475.2000',
#    '4. close': '477.7300',
#    '5. volume': '34615102'},
#   '2025-12-02': {'1. open': '486.7150',
#    '2. high': '493.4999',
#    '3. low': '486.3200',
#    '4. close': '490.0000',
#    '5. volume': '19562722'},
#   '2025-12-01': {'1. open': '488.4350',
#    '2. high': '489.8599',
#    '3. low': '484.6475',
#    '4. close': '486.7400',
#    '5. volume': '23963993'},
#   '2025-11-28': {'1. open': '487.5950',
#    '2. high': '492.6300',
#    '3. low': '486.6500',
#    '4. close': '492.0100',
#    '5. volume': '14386730'},
#   '2025-11-26': {'1. open': '486.3100',
#    '2. high': '488.3100',
#    '3. low': '481.2000',
#    '4. close': '485.5000',
#    '5. volume': '25709079'},
#   '2025-11-25': {'1. open': '474.0700',
#    '2. high': '479.1500',
#    '3. low': '464.8900',
#    '4. close': '476.9900',
#    '5. volume': '28019793'},
#   '2025-11-24': {'1. open': '475.0000',
#    '2. high': '476.9000',
#    '3. low': '468.0200',
#    '4. close': '474.0000',
#    '5. volume': '34421046'},
#   '2025-11-21': {'1. open': '478.5000',
#    '2. high': '478.9200',
#    '3. low': '468.2700',
#    '4. close': '472.1200',
#    '5. volume': '31769248'},
#   '2025-11-20': {'1. open': '492.7100',
#    '2. high': '493.5700',
#    '3. low': '475.5000',
#    '4. close': '478.4300',
#    '5. volume': '26802542'},
#   '2025-11-19': {'1. open': '490.1000',
#    '2. high': '495.1872',
#    '3. low': '482.8300',
#    '4. close': '487.1200',
#    '5. volume': '23245314'},
#   '2025-11-18': {'1. open': '495.3650',
#    '2. high': '502.9800',
#    '3. low': '486.7800',
#    '4. close': '493.7900',
#    '5. volume': '33815114'},
#   '2025-11-17': {'1. open': '508.4500',
#    '2. high': '512.1200',
#    '3. low': '504.9100',
#    '4. close': '507.4900',
#    '5. volume': '19092752'},
#   '2025-11-14': {'1. open': '498.2300',
#    '2. high': '511.6000',
#    '3. low': '497.4400',
#    '4. close': '510.1800',
#    '5. volume': '28505746'},
#   '2025-11-13': {'1. open': '510.3100',
#    '2. high': '513.5000',
#    '3. low': '501.2900',
#    '4. close': '503.2900',
#    '5. volume': '25273114'},
#   '2025-11-12': {'1. open': '509.3550',
#    '2. high': '511.6700',
#    '3. low': '499.1201',
#    '4. close': '511.1400',
#    '5. volume': '26574851'},
#   '2025-11-11': {'1. open': '504.8000',
#    '2. high': '509.6000',
#    '3. low': '502.3488',
#    '4. close': '508.6800',
#    '5. volume': '17980020'},
#   '2025-11-10': {'1. open': '500.0350',
#    '2. high': '506.8500',
#    '3. low': '498.8000',
#    '4. close': '506.0000',
#    '5. volume': '26101480'},
#   '2025-11-07': {'1. open': '496.9450',
#    '2. high': '499.3770',
#    '3. low': '493.2500',
#    '4. close': '496.8200',
#    '5. volume': '24019764'},
#   '2025-11-06': {'1. open': '505.6600',
#    '2. high': '505.7000',
#    '3. low': '495.8100',
#    '4. close': '497.1000',
#    '5. volume': '27406496'},
#   '2025-11-05': {'1. open': '513.3000',
#    '2. high': '514.8300',
#    '3. low': '506.5750',
#    '4. close': '507.1600',
#    '5. volume': '22883851'},
#   '2025-11-04': {'1. open': '511.7600',
#    '2. high': '515.5500',
#    '3. low': '507.8400',
#    '4. close': '514.3300',
#    '5. volume': '20958663'},
#   '2025-11-03': {'1. open': '519.8050',
#    '2. high': '524.9600',
#    '3. low': '514.5900',
#    '4. close': '517.0300',
#    '5. volume': '22374742'},
#   '2025-10-31': {'1. open': '528.8750',
#    '2. high': '529.3200',
#    '3. low': '515.1000',
#    '4. close': '517.8100',
#    '5. volume': '34006424'},
#   '2025-10-30': {'1. open': '530.4800',
#    '2. high': '534.9700',
#    '3. low': '522.1200',
#    '4. close': '525.7600',
#    '5. volume': '41023088'},
#   '2025-10-29': {'1. open': '544.9400',
#    '2. high': '546.2700',
#    '3. low': '536.7287',
#    '4. close': '541.5500',
#    '5. volume': '36023004'},
#   '2025-10-28': {'1. open': '550.0000',
#    '2. high': '553.7200',
#    '3. low': '540.7700',
#    '4. close': '542.0700',
#    '5. volume': '29986683'},
#   '2025-10-27': {'1. open': '531.7800',
#    '2. high': '534.5800',
#    '3. low': '529.0100',
#    '4. close': '531.5200',
#    '5. volume': '18734716'},
#   '2025-10-24': {'1. open': '522.7900',
#    '2. high': '525.3450',
#    '3. low': '520.7100',
#    '4. close': '523.6100',
#    '5. volume': '15532360'},
#   '2025-10-23': {'1. open': '522.4600',
#    '2. high': '523.9500',
#    '3. low': '518.6100',
#    '4. close': '520.5600',
#    '5. volume': '14023532'},
#   '2025-10-22': {'1. open': '521.1500',
#    '2. high': '525.2300',
#    '3. low': '517.7100',
#    '4. close': '520.5400',
#    '5. volume': '18962694'},
#   '2025-10-21': {'1. open': '517.5000',
#    '2. high': '518.6900',
#    '3. low': '513.0400',
#    '4. close': '517.6600',
#    '5. volume': '15586204'},
#   '2025-10-20': {'1. open': '514.6100',
#    '2. high': '518.7000',
#    '3. low': '513.4300',
#    '4. close': '516.7900',
#    '5. volume': '14665620'},
#   '2025-10-17': {'1. open': '509.0400',
#    '2. high': '515.4800',
#    '3. low': '507.3100',
#    '4. close': '513.5800',
#    '5. volume': '19867765'},
#   '2025-10-16': {'1. open': '512.5800',
#    '2. high': '516.8500',
#    '3. low': '508.1300',
#    '4. close': '511.6100',
#    '5. volume': '15559565'},
#   '2025-10-15': {'1. open': '514.9550',
#    '2. high': '517.1900',
#    '3. low': '510.0000',
#    '4. close': '513.4300',
#    '5. volume': '14694654'},
#   '2025-10-14': {'1. open': '510.2250',
#    '2. high': '515.2820',
#    '3. low': '506.0000',
#    '4. close': '513.5700',
#    '5. volume': '14684300'},
#   '2025-10-13': {'1. open': '516.4100',
#    '2. high': '516.4100',
#    '3. low': '511.6800',
#    '4. close': '514.0500',
#    '5. volume': '14284238'},
#   '2025-10-10': {'1. open': '519.6400',
#    '2. high': '523.5800',
#    '3. low': '509.6300',
#    '4. close': '510.9600',
#    '5. volume': '24133840'},
#   '2025-10-09': {'1. open': '522.3350',
#    '2. high': '524.3250',
#    '3. low': '517.4000',
#    '4. close': '522.4000',
#    '5. volume': '18343602'},
#   '2025-10-08': {'1. open': '523.2800',
#    '2. high': '526.9500',
#    '3. low': '523.0900',
#    '4. close': '524.8500',
#    '5. volume': '13363447'},
#   '2025-10-07': {'1. open': '528.2850',
#    '2. high': '529.8000',
#    '3. low': '521.4400',
#    '4. close': '523.9800',
#    '5. volume': '14615208'},
#   '2025-10-06': {'1. open': '518.6100',
#    '2. high': '531.0300',
#    '3. low': '518.2000',
#    '4. close': '528.5700',
#    '5. volume': '21388581'}}}

# %%
df = pd.DataFrame(data)
df["Meta Data"]
# Out:
# 1. Information       Daily Prices (open, high, low, close) and Volumes
# 2. Symbol                                                         MSFT
# 3. Last Refreshed                                           2026-02-27
# 4. Output Size                                                 Compact
# 5. Time Zone                                                US/Eastern
#                                            ...
# 2025-10-10                                                         NaN
# 2025-10-09                                                         NaN
# 2025-10-08                                                         NaN
# 2025-10-07                                                         NaN
# 2025-10-06                                                         NaN
# Name: Meta Data, Length: 105, dtype: object
