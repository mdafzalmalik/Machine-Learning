# %%
# turning image in numpy array

# %%
import numpy as np

# %% [markdown]
# <img src="images/panda.jpg"/>

# %%
from matplotlib.image import imread

# %%
panda = imread("images/panda.jpg")
type(panda)
# Out:
# numpy.ndarray

# %%
panda
# Out:
# array([[[13, 29, 18],
#         [13, 29, 18],
#         [15, 28, 18],
#         ...,
#         [41, 33, 22],
#         [42, 32, 22],
#         [42, 32, 22]],
#
#        [[13, 29, 18],
#         [13, 29, 18],
#         [15, 28, 18],
#         ...,
#         [41, 33, 22],
#         [42, 32, 22],
#         [42, 32, 22]],
#
#        [[12, 28, 17],
#         [12, 28, 17],
#         [14, 27, 17],
#         ...,
#         [43, 35, 24],
#         [44, 34, 24],
#         [44, 34, 24]],
#
#        ...,
#
#        [[38, 23, 16],
#         [38, 23, 16],
#         [39, 24, 17],
#         ...,
#         [ 7,  7,  9],
#         [ 6,  6,  8],
#         [ 6,  6,  8]],
#
#        [[35, 20, 13],
#         [34, 19, 12],
#         [33, 19, 10],
#         ...,
#         [ 6,  6,  8],
#         [ 6,  6,  8],
#         [ 6,  6,  8]],
#
#        [[36, 21, 14],
#         [33, 18, 11],
#         [30, 16,  7],
#         ...,
#         [ 6,  6,  8],
#         [ 6,  6,  8],
# ...
