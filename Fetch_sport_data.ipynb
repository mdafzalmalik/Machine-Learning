# %%
import requests
import pandas as pd

# %%
url = "https://odds.p.rapidapi.com/v4/sports/upcoming/odds"

params = {
    "regions": "us",
    "oddsFormat": "decimal",
    "markets": "h2h,spreads",  # %2C in URL = ,
    "dateFormat": "iso"
}

headers = {
    "x-rapidapi-host": "odds.p.rapidapi.com",
    "x-rapidapi-key": "885b3131d9msh816a48785e2f145p100ad9jsnae97fdad8ab0"
}

response = requests.get(url, headers=headers, params=params)

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
data = response.json()

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                  id               sport_key   sport_title  \
# 0  3c03ad555c68d9d208e060acc207140c        soccer_efl_champ  Championship
# 1  581a73fb2139a431e0fe4ad9fe0615b1  soccer_england_league2      League 2
# 2  0292702c2f31f3525bb191ca2fc794cb  soccer_england_league2      League 2
# 3  98dbfa8a9ca607b8757dc130d4a3a3d7  soccer_england_league1      League 1
# 4  e3ba556655a8835a3c9d92a62d3172dc  soccer_england_league2      League 2
# 5  2629958db376d0c1b0e6822eadd4fd39        soccer_efl_champ  Championship
# 6  de5e84836de13c20827bfec4975745b7  soccer_england_league1      League 1
# 7  e15f870f5ab00909bac3e7b0eb02cbb8  soccer_england_league1      League 1
#
#           commence_time         home_team           away_team  \
# 0  2026-01-01T12:30:00Z  Blackburn Rovers         Wrexham AFC
# 1  2026-01-01T15:00:00Z      Notts County  Accrington Stanley
# 2  2026-01-01T15:00:00Z            Barnet        Crawley Town
# 3  2026-01-01T15:00:00Z    Wigan Athletic            Barnsley
# 4  2026-01-01T15:00:00Z            Barrow        Salford City
# 5  2026-01-01T15:00:00Z           Watford     Birmingham City
# 6  2026-01-01T15:00:00Z         Port Vale           Blackpool
# 7  2026-01-01T15:00:00Z  Doncaster Rovers    Bolton Wanderers
#
#                                           bookmakers
# 0  [{'key': 'betmgm', 'title': 'BetMGM', 'last_up...
# 1  [{'key': 'betrivers', 'title': 'BetRivers', 'l...
# 2  [{'key': 'betrivers', 'title': 'BetRivers', 'l...
# 3  [{'key': 'betrivers', 'title': 'BetRivers', 'l...
# 4  [{'key': 'betrivers', 'title': 'BetRivers', 'l...
# 5  [{'key': 'fanduel', 'title': 'FanDuel', 'last_...
# 6  [{'key': 'betrivers', 'title': 'BetRivers', 'l...
# 7  [{'key': 'betrivers', 'title': 'BetRivers', 'l...
