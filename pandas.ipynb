# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(["apple","banana","guava"])
s1
# Out:
# 0     apple
# 1    banana
# 2     guava
# dtype: object

# %%
s2 = pd.Series([20,30,40,50,60])
s2
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
s3 = pd.Series(["Aman","Amir","Anis","Ashif","Rizwan"], index=[1,2,3,4,5])
s3
# Out:
# 1      Aman
# 2      Amir
# 3      Anis
# 4     Ashif
# 5    Rizwan
# dtype: object

# %%
# dataframes

# %%
data1 = [
    ["Afzal","Aman","Amir","Anis"],
    [100,89,80,10],
    [100,89,80,10],
    [90,79,79,9],
    [50,59,70,5],
]
df1 = pd.DataFrame(data1, columns=["marks","percentage","iq","package"])
df1
# Out:
#    marks percentage    iq package
# 0  Afzal       Aman  Amir    Anis
# 1    100         89    80      10
# 2    100         89    80      10
# 3     90         79    79       9
# 4     50         59    70       5

# %%
dct = {
    "name":["Afzal","Aman","Amir"],
    "marks":[100,np.nan,50],
    "percentage":[89,79,59],
    "iq":[80,78,70],
    "package":[10,8,5]
}
df2 = pd.DataFrame(dct)
df2.set_index("name", inplace=True)
df2
# Out:
#        marks  percentage  iq  package
# name
# Afzal  100.0          89  80       10
# Aman     NaN          79  78        8
# Amir    50.0          59  70        5

# %%
data = pd.read_csv("data/data.csv")
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# data.to_string()  #print entire data

# %%
data.shape
# Out:
# (169, 4)

# %%
data.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
data.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
data.values
# Out:
# array([[  60. ,  110. ,  130. ,  409.1],
#        [  60. ,  117. ,  145. ,  479. ],
#        [  60. ,  103. ,  135. ,  340. ],
#        [  45. ,  109. ,  175. ,  282.4],
#        [  45. ,  117. ,  148. ,  406. ],
#        [  60. ,  102. ,  127. ,  300. ],
#        [  60. ,  110. ,  136. ,  374. ],
#        [  45. ,  104. ,  134. ,  253.3],
#        [  30. ,  109. ,  133. ,  195.1],
#        [  60. ,   98. ,  124. ,  269. ],
#        [  60. ,  103. ,  147. ,  329.3],
#        [  60. ,  100. ,  120. ,  250.7],
#        [  60. ,  106. ,  128. ,  345.3],
#        [  60. ,  104. ,  132. ,  379.3],
#        [  60. ,   98. ,  123. ,  275. ],
#        [  60. ,   98. ,  120. ,  215.2],
#        [  60. ,  100. ,  120. ,  300. ],
#        [  45. ,   90. ,  112. ,    nan],
#        [  60. ,  103. ,  123. ,  323. ],
#        [  45. ,   97. ,  125. ,  243. ],
#        [  60. ,  108. ,  131. ,  364.2],
#        [  45. ,  100. ,  119. ,  282. ],
#        [  60. ,  130. ,  101. ,  300. ],
# ...

# %%
data.head(2)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0

# %%
data.tail(2)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
data.sample(n=10).set_index(pd.Index(range(1, 11)))
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 1         30     90       107     105.3
# 2         90    100       127     700.0
# 3         45    109       175     282.4
# 4         30     80       120     240.9
# 5         45    104       129     266.0
# 6         60    100       120     300.0
# 7         30     93       128     124.0
# 8         60    111       151     368.5
# 9         60    100       120     300.0
# 10        60    101       124     299.0

# %%
df2
# Out:
#        marks  percentage  iq  package
# name
# Afzal  100.0          89  80       10
# Aman     NaN          79  78        8
# Amir    50.0          59  70        5

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Afzal to Amir
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   marks       2 non-null      float64
#  1   percentage  3 non-null      int64
#  2   iq          3 non-null      int64
#  3   package     3 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 120.0+ bytes

# %%
df2
# Out:
#        marks  percentage  iq  package
# name
# Afzal  100.0          89  80       10
# Aman     NaN          79  78        8
# Amir    50.0          59  70        5

# %%
data.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(7)

# %%
df1
# Out:
#    marks percentage    iq package
# 0  Afzal       Aman  Amir    Anis
# 1    100         89    80      10
# 2    100         89    80      10
# 3     90         79    79       9
# 4     50         59    70       5

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df2
# Out:
#        marks  percentage  iq  package
# name
# Afzal  100.0          89  80       10
# Aman     NaN          79  78        8
# Amir    50.0          59  70        5

# %%
df2.rename(columns={"percentage": "percentage (%)"})
# Out:
#        marks  percentage (%)  iq  package
# name
# Afzal  100.0              89  80       10
# Aman     NaN              79  78        8
# Amir    50.0              59  70        5

# %%
df2.index = ["1st", "2nd", "3rd"]
df2
# Out:
#      marks  percentage  iq  package
# 1st  100.0          89  80       10
# 2nd    NaN          79  78        8
# 3rd   50.0          59  70        5

# %%
df2
# Out:
#      marks  percentage  iq  package
# 1st  100.0          89  80       10
# 2nd    NaN          79  78        8
# 3rd   50.0          59  70        5

# %%
df2.reset_index()
# Out:
#   index  marks  percentage  iq  package
# 0   1st  100.0          89  80       10
# 1   2nd    NaN          79  78        8
# 2   3rd   50.0          59  70        5

# %%
data.sum(axis=0)
# Out:
# Duration    10790.0
# Pulse       18161.0
# Maxpulse    22654.0
# Calories    61629.6
# dtype: float64

# %%
data.sum(axis=1)
# Out:
# 0      709.1
# 1      801.0
# 2      638.0
# 3      611.4
# 4      716.0
#        ...
# 164    595.8
# 165    615.0
# 166    630.2
# 167    665.4
# 168    680.4
# Length: 169, dtype: float64

# %%
data.mean()
# Out:
# Duration     63.846154
# Pulse       107.461538
# Maxpulse    134.047337
# Calories    375.790244
# dtype: float64

# %%
data.median()
# Out:
# Duration     60.0
# Pulse       105.0
# Maxpulse    131.0
# Calories    318.6
# dtype: float64

# %%
data.std()
# Out:
# Duration     42.299949
# Pulse        14.510259
# Maxpulse     16.450434
# Calories    266.379919
# dtype: float64

# %%
data.var()
# Out:
# Duration     1789.285714
# Pulse         210.547619
# Maxpulse      270.616793
# Calories    70958.261377
# dtype: float64

# %%
data.min()
# Out:
# Duration     15.0
# Pulse        80.0
# Maxpulse    100.0
# Calories     50.3
# dtype: float64

# %%
data.max()
# Out:
# Duration     300.0
# Pulse        159.0
# Maxpulse     184.0
# Calories    1860.4
# dtype: float64

# %%
data[["Duration", "Maxpulse"]]
# Out:
#      Duration  Maxpulse
# 0          60       130
# 1          60       145
# 2          60       135
# 3          45       175
# 4          45       148
# ..        ...       ...
# 164        60       140
# 165        60       145
# 166        60       145
# 167        75       150
# 168        75       150
#
# [169 rows x 2 columns]

# %%
type(data["Duration"])
# Out:
# pandas.core.series.Series

# %%
data.index
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
data.index = [f'row_{i}' for i in range(0,169)]
data
# Out:
#          Duration  Pulse  Maxpulse  Calories
# row_0          60    110       130     409.1
# row_1          60    117       145     479.0
# row_2          60    103       135     340.0
# row_3          45    109       175     282.4
# row_4          45    117       148     406.0
# ...           ...    ...       ...       ...
# row_164        60    105       140     290.8
# row_165        60    110       145     300.0
# row_166        60    115       145     310.2
# row_167        75    120       150     320.4
# row_168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(data.loc["row_4", "Maxpulse"])
# Out:
# 148

# %%
print(data.iloc[4,1])
# Out:
# 117

# %%
data
# Out:
#          Duration  Pulse  Maxpulse  Calories
# row_0          60    110       130     409.1
# row_1          60    117       145     479.0
# row_2          60    103       135     340.0
# row_3          45    109       175     282.4
# row_4          45    117       148     406.0
# ...           ...    ...       ...       ...
# row_164        60    105       140     290.8
# row_165        60    110       145     300.0
# row_166        60    115       145     310.2
# row_167        75    120       150     320.4
# row_168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data.iloc[:4]
# Out:
#        Duration  Pulse  Maxpulse  Calories
# row_0        60    110       130     409.1
# row_1        60    117       145     479.0
# row_2        60    103       135     340.0
# row_3        45    109       175     282.4

# %%
data.iloc[[2,4,8]]
# Out:
#        Duration  Pulse  Maxpulse  Calories
# row_2        60    103       135     340.0
# row_4        45    117       148     406.0
# row_8        30    109       133     195.1

# %%
data.loc["row_0":"row_6":2]
# Out:
#        Duration  Pulse  Maxpulse  Calories
# row_0        60    110       130     409.1
# row_2        60    103       135     340.0
# row_4        45    117       148     406.0
# row_6        60    110       136     374.0

# %%
data.loc[["row_9", "row_25", "row_89"]]
# Out:
#         Duration  Pulse  Maxpulse  Calories
# row_9         60     98       124     269.0
# row_25        60    100       120     250.0
# row_89        20     83       107      50.3

# %%
data.iloc[:3,:3]
# Out:
#        Duration  Pulse  Maxpulse
# row_0        60    110       130
# row_1        60    117       145
# row_2        60    103       135

# %%
print(data.to_string)
# Out:
# <bound method DataFrame.to_string of          Duration  Pulse  Maxpulse  Calories
# row_0          60    110       130     409.1
# row_1          60    117       145     479.0
# row_2          60    103       135     340.0
# row_3          45    109       175     282.4
# row_4          45    117       148     406.0
# ...           ...    ...       ...       ...
# row_164        60    105       140     290.8
# row_165        60    110       145     300.0
# row_166        60    115       145     310.2
# row_167        75    120       150     320.4
# row_168        75    125       150     330.4
#
# [169 rows x 4 columns]>

# %%
data[data["Duration"] == 20][["Pulse", "Calories"]]
# Out:
#          Pulse  Calories
# row_58     153     226.4
# row_64     110     131.4
# row_68     106     110.4
# row_89      83      50.3
# row_94     150     127.4
# row_95     151     229.4
# row_100     95      77.7
# row_135    136     189.0
# row_139    141     222.4

# %%
data[data["Maxpulse"] > 165][["Maxpulse"]].count()
# Out:
# Maxpulse    13
# dtype: int64

# %%
data[data["Maxpulse"] > 165].shape[0]
# Out:
# 13

# %%
data.head(4)
# Out:
#        Duration  Pulse  Maxpulse  Calories
# row_0        60    110       130     409.1
# row_1        60    117       145     479.0
# row_2        60    103       135     340.0
# row_3        45    109       175     282.4

# %%
data[(data["Duration"] == 60) & (data["Maxpulse"] > 165)].shape[0]
# Out:
# 2

# %%
car_sales = pd.read_csv("data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,\.]', '', regex=True).astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
data.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000
